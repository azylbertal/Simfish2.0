# %%
import pandas as pd

# load bout_data_thomas_etal.csv
bout_data = pd.read_csv('../bout_data_thomas_etal.csv')

#

# %%
bout_data
# Out:
#         fishID  age cond  cluster  hunt  hunt_ID    energy bout_type
# 0           10    5  w2w        3     0      NaN  0.346283        Rt
# 1           10    5  w2w        1     0      NaN  0.112049       HAT
# 2           10    5  w2w        4     0      NaN  0.013294        S1
# 3           10    5  w2w        6     0      NaN  0.028554         C
# 4           10    5  w2w        5     0      NaN  0.015963         A
# ...        ...  ...  ...      ...   ...      ...       ...       ...
# 107281      29    8  v2v        7     0      NaN  0.127347        S2
# 107282      29    8  v2v        7     0      NaN  0.204143        S2
# 107283      29    8  v2v        3     0      NaN  0.249877        Rt
# 107284      29    8  v2v        3     0      NaN  0.230064        Rt
# 107285      29    8  v2v        1     0      NaN  0.363675       HAT
#
# [107286 rows x 8 columns]

# %%
# find the mean energy for each bout_type, but only for hunt=1 and age=5
mean_energy = bout_data[(bout_data['hunt'] == 1) & (bout_data['age'] == 5)].groupby('bout_type')['energy'].mean()

# %%
mean_energy
# Out:
# bout_type
# A      0.029172
# C      0.028726
# HAT    0.150897
# Jt     0.037116
# Rt     0.161552
# S1     0.018561
# S2     0.109563
# Name: energy, dtype: float64
